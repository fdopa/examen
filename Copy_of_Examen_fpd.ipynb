# %% [markdown]
# <a href="https://colab.research.google.com/github/fdopa/examen/blob/main/Copy_of_Examen_fpd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instrucciones para resolver el examen en Google Colab:
#
# 1. Acceso al examen:
#    - Accede a Google Colab a través de tu navegador web utilizando el enlace proporcionado por el profesor.
#
# 2. Crear una copia privada:
#    - Una vez en Google Colab, elige la opción "Archivo" en la barra de menú.
#    - Luego, selecciona "Guardar una copia en Drive" para crear una copia privada del examen en tu cuenta de Google Drive.
#
# 3. Leer las instrucciones:
#    - Lee cuidadosamente las instrucciones y preguntas del examen. Asegúrate de entender lo que se te está pidiendo antes de comenzar a responder.
#
# 4. Responder las preguntas:
#    - Utiliza las celdas de código y de texto proporcionadas para responder a las preguntas del examen.
#    - Si es necesario, crea nuevas celdas para organizar tu respuesta o escribir comentarios explicativos.
#
# 5. Ejecución de código:
#    - Si hay preguntas que requieren escribir código, asegúrate de ejecutar las celdas de código para obtener los resultados deseados.
#    - Si obtienes resultados incorrectos, revisa tu código y corrige los errores antes de continuar.
#
# 6. Guardar los cambios:
#    - Asegúrate de guardar regularmente tus cambios en la copia privada del examen en Google Drive para evitar perder el progreso.
#
# 7. Tiempo límite:
#    - Respeta el tiempo límite establecido para completar el examen. Administra tu tiempo de manera efectiva para responder todas las preguntas.
#
# 8. No acceder a recursos externos:
#    - Durante el examen, no está permitido acceder a recursos externos como libros, apuntes o internet. El examen debe resolverse de manera individual.
#
# 9. Evitar copiar respuestas:
#    - Respeta la integridad académica y evita copiar respuestas de otros compañeros. El examen debe reflejar tu comprensión y conocimiento personal.
#
#
# Recuerda que estas son instrucciones generales para resolver un examen en Google Colab. Es importante que el profesor proporcione instrucciones específicas y detalladas para cada examen. Asegúrate de seguir las indicaciones del profesor y cumplir con las reglas establecidas para una experiencia de examen justa y equitativa. ¡Buena suerte en tu examen en Google Colab!

# %%
# @title Descargar datos
import requests as req

URL = 'https://gist.githubusercontent.com/javierIA/06da309a089278be218daf66e02875ab/raw/d0bfabd94c27ad954cba63683d04d460660387f8/salarios.csv'
file = req.get(URL, allow_redirects=True)

open('salarios.csv', 'wb').write(file.content)
# Out:
# 1103

# %% [markdown]
# ## Asegúrate de proporcionar la ruta correcta hacia el archivo CSV o que el archivo esté en la misma ubicación que este notebook.

# %%
import pandas as pd

# Cargar los datos en la variable df
df=pd.read_csv('salarios.csv', encoding = "ISO-8859-1")
print(df.head(5))
# Verificar que los datos se hayan cargado correctamente
print(df)
# Out:
#    Periodo  Unnamed: 1     Total  1_salario_minimo  2_salario_minimo  \
# 0     2017           1  51859895           7442463          14262160
# 1     2017           2  52198611           7566408          14118747
# 2     2017           3  52438646           7355639          13682660
# 3     2017           4  52865845           7926332          14215650
# 4     2018           1  52876916           8645273          15253962
#
#    3_salario_minimo  5_salario_minimo  mas de 5_salario_minimo  \
# 0          11218801           6601395                  2704520
# 1          10939869           6555065                  2776570
# 2          11081749           6695729                  2722520
# 3          10531765           6695812                  2429320
# 4           9754514           6707166                  2272438
#
#    No recibe ingresos  No especificado
# 0             3133797          6496759
# 1             3337521          6904431
# 2             3437846          7462503
# 3             3421033          7645933
# 4             2965555          7278008
#     Periodo  Unnamed: 1     Total  1_salario_minimo  2_salario_minimo  \
# 0      2017           1  51859895           7442463          14262160
# 1      2017           2  52198611           7566408          14118747
# 2      2017           3  52438646           7355639          13682660
# 3      2017           4  52865845           7926332          14215650
# 4      2018           1  52876916           8645273          15253962
# 5      2018           2  53785257           8705172          15287116
# 6      2018           3  54027997           8547030          15112727
# 7      2018           4  54194608           8663936          15038091
# 8      2019           1  54152266          10642543          17141160
# 9      2019           2  54936719          10891594          17552729
# 10     2019           3  55201939          10948633          17531173
# 11     2019           4  55683450          11060229          17578323
# 12     2020           1  55352304          12533197          19781852
#
#     3_salario_minimo  5_salario_minimo  mas de 5_salario_minimo  \
# 0           11218801           6601395                  2704520
# 1           10939869           6555065                  2776570
# 2           11081749           6695729                  2722520
# 3           10531765           6695812                  2429320
# 4            9754514           6707166                  2272438
# 5            9739678           6936174                  2419355
# 6            9852659           6908797                  2405725
# 7           10001777           6921736                  2456938
# 8            9818858           4522674                  1741491
# 9            9919901           4437659                  1831552
# 10          10038381           4629662                  1810804
# 11          10056100           4972246                  2010414
# 12           8613773           3715640                  1534613
#
#     No recibe ingresos  No especificado
# 0              3133797          6496759
# 1              3337521          6904431
# 2              3437846          7462503
# 3              3421033          7645933
# 4              2965555          7278008
# 5              3254898          7442864
# 6              3480221          7720838
# 7              3344211          7767919
# 8              3123910          7161630
# 9              3219868          7083416
# 10             3485828          6757458
# 11             3358459          6647679
# 12             2908620          6264609

# %%
# Muestra las primeras 5 filas del DataFrame
#hit al azar
df.sample(5)
# Out:
#     Periodo  Unnamed: 1     Total  1_salario_minimo  2_salario_minimo  \
# 6      2018           3  54027997           8547030          15112727
# 2      2017           3  52438646           7355639          13682660
# 8      2019           1  54152266          10642543          17141160
# 0      2017           1  51859895           7442463          14262160
# 12     2020           1  55352304          12533197          19781852
#
#     3_salario_minimo  5_salario_minimo  mas de 5_salario_minimo  \
# 6            9852659           6908797                  2405725
# 2           11081749           6695729                  2722520
# 8            9818858           4522674                  1741491
# 0           11218801           6601395                  2704520
# 12           8613773           3715640                  1534613
#
#     No recibe ingresos  No especificado
# 6              3480221          7720838
# 2              3437846          7462503
# 8              3123910          7161630
# 0              3133797          6496759
# 12             2908620          6264609

# %%
# @title Estadistica de daframe
print("\nEstadísticas básicas del DataFrame:")

df.describe().T
# Out:
# Estadísticas básicas del DataFrame:
#                          count          mean           std         min  \
# Periodo                   13.0  2.018154e+03  9.870962e-01      2017.0
# Unnamed: 1                13.0  2.384615e+00  1.192928e+00         1.0
# Total                     13.0  5.381342e+07  1.273143e+06  51859895.0
# 1_salario_minimo          13.0  9.302188e+06  1.695160e+06   7355639.0
# 2_salario_minimo          13.0  1.588895e+07  1.838962e+06  13682660.0
# 3_salario_minimo          13.0  1.012060e+07  6.920934e+05   8613773.0
# 5_salario_minimo          13.0  5.869212e+06  1.198729e+06   3715640.0
# mas de 5_salario_minimo   13.0  2.239712e+06  4.112917e+05   1534613.0
# No recibe ingresos        13.0  3.267059e+06  1.882936e+05   2908620.0
# No especificado           13.0  7.125696e+06  4.854288e+05   6264609.0
#
#                                 25%         50%         75%         max
# Periodo                      2017.0      2018.0      2019.0      2020.0
# Unnamed: 1                      1.0         2.0         3.0         4.0
# Total                    52865845.0  54027997.0  54936719.0  55683450.0
# 1_salario_minimo          7926332.0   8663936.0  10891594.0  12533197.0
# 2_salario_minimo         14262160.0  15253962.0  17531173.0  19781852.0
# 3_salario_minimo          9818858.0  10001777.0  10531765.0  11218801.0
# 5_salario_minimo          4629662.0   6601395.0   6707166.0   6936174.0
# mas de 5_salario_minimo   1831552.0   2405725.0   2456938.0   2776570.0
# No recibe ingresos        3133797.0   3337521.0   3421033.0   3485828.0
# No especificado           6757458.0   7161630.0   7462503.0   7767919.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Periodo                  13 non-null     int64
#  1   Unnamed: 1               13 non-null     int64
#  2   Total                    13 non-null     int64
#  3   1_salario_minimo         13 non-null     int64
#  4   2_salario_minimo         13 non-null     int64
#  5   3_salario_minimo         13 non-null     int64
#  6   5_salario_minimo         13 non-null     int64
#  7   mas de 5_salario_minimo  13 non-null     int64
#  8   No recibe ingresos       13 non-null     int64
#  9   No especificado          13 non-null     int64
# dtypes: int64(10)
# memory usage: 1.1 KB

# %%
# @title Filtro y seleciona datos
# @markdown Seleciona los datos de la columna periodo mayor a 2018
#filtro_periodo =  > 2018
print("\nFilas donde la Periodo es mayor a 2018:")

#print(df.Periodo['filtro_periodo'])
# import pandas as pd

datos=pd.read_csv('salarios.csv')
#print (datos['Periodo'])
per=datos['Periodo']

print (per[per > 2018])
# Out:
# Filas donde la Periodo es mayor a 2018:
# 8     2019
# 9     2019
# 10    2019
# 11    2019
# 12    2020
# Name: Periodo, dtype: int64

# %%
# @title Remplaza la columnas
# @markdown Remplaza el nombre columnas a otras la segundo columna no tiene el nombre, este se refiere al timestre favor actualizar el nombre

print("Columnas antes de la modificación:")
print(df.columns)
# Index(['Periodo', 'Unnamed: 1', 'Total', '1_salario_minimo',
#        '2_salario_minimo', '3_salario_minimo', '5_salario_minimo',
#        'mas de 5_salario_minimo', 'No recibe ingresos', 'No especificado'],
#       dtype='object')

df.rename(columns={"Perido":"Periodo","Unnamed: 1":"Trimestre"}, inplace=True)

print(df.columns)
# df.info()
df.sample(5)
# Out:
# Columnas antes de la modificación:
# Index(['Periodo', 'Trimestre', 'Total', '1_salario_minimo', '2_salario_minimo',
#        '3_salario_minimo', '5_salario_minimo', 'mas de 5_salario_minimo',
#        'No recibe ingresos', 'No especificado'],
#       dtype='object')
# Index(['Periodo', 'Trimestre', 'Total', '1_salario_minimo', '2_salario_minimo',
#        '3_salario_minimo', '5_salario_minimo', 'mas de 5_salario_minimo',
#        'No recibe ingresos', 'No especificado'],
#       dtype='object')
#     Periodo  Trimestre     Total  1_salario_minimo  2_salario_minimo  \
# 9      2019          2  54936719          10891594          17552729
# 7      2018          4  54194608           8663936          15038091
# 12     2020          1  55352304          12533197          19781852
# 6      2018          3  54027997           8547030          15112727
# 11     2019          4  55683450          11060229          17578323
#
#     3_salario_minimo  5_salario_minimo  mas de 5_salario_minimo  \
# 9            9919901           4437659                  1831552
# 7           10001777           6921736                  2456938
# 12           8613773           3715640                  1534613
# 6            9852659           6908797                  2405725
# 11          10056100           4972246                  2010414
#
#     No recibe ingresos  No especificado
# 9              3219868          7083416
# 7              3344211          7767919
# 12             2908620          6264609
# 6              3480221          7720838
# 11             3358459          6647679
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6633775898264270747 = autoviz.get_df('df_6633775898264270747')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6633775898264270747, *['Periodo'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6633775898264270747 = autoviz.get_df('df_6633775898264270747')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6633775898264270747, *['Trimestre'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6633775898264270747 = autoviz.get_df('df_6633775898264270747')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6633775898264270747, *['Total'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6633775898264270747 = autoviz.get_df('df_6633775898264270747')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6633775898264270747, *['1_salario_minimo'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6633775898264270747 = autoviz.get_df('df_6633775898264270747')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6633775898264270747, *['Periodo'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6633775898264270747 = autoviz.get_df('df_6633775898264270747')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6633775898264270747, *['Trimestre'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6633775898264270747 = autoviz.get_df('df_6633775898264270747')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6633775898264270747, *['Total'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6633775898264270747 = autoviz.get_df('df_6633775898264270747')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6633775898264270747, *['1_salario_minimo'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6633775898264270747 = autoviz.get_df('df_6633775898264270747')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_6633775898264270747, *[[['Periodo', 'Trimestre'], ['Trimestre', 'Total'], ['Total', '1_salario_minimo'], ['1_salario_minimo', '2_salario_minimo']]], **{})
# chart

# %% [markdown]
# ![Screenshot from 2023-07-24 15-27-22.png](data:image/png;base64,...)

# %%
# Favor usar el nombre trismetre
# Pista la columna se llama "Unnamed: 1"
# df.rename(columns={}, inplace=True)

df.rename(columns={"Perido":"Periodo","Unnamed: 1":"Trimestre"}, inplace=True)
print(df.columns)
# Out:
# Index(['Periodo', 'Trimestre', 'Total', '1_salario_minimo', '2_salario_minimo',
#        '3_salario_minimo', '5_salario_minimo', 'mas de 5_salario_minimo',
#        'No recibe ingresos', 'No especificado'],
#       dtype='object')

# %%
# @title Calcular el total de ingresos para cada año y período

# total_por_periodo = df.groupby('Total')
# total_por_periodo

print("Total en el periodo")
df['Total'].sum()
# Out:
# Total en el periodo
# 699574453

# %% [markdown]
# **Alerta** . No tiene datos nulos

# %%
valores_nulos = df.isnull().sum()

porcentajes_nulos_ordenados
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-fd49e5328c8e> in <cell line: 3>()
#       1 valores_nulos = df.isnull().sum()
#       2
# ----> 3 porcentajes_nulos_ordenados
#
# NameError: name 'porcentajes_nulos_ordenados' is not defined

# %%
import matplotlib.pyplot as plt

# Graficar los ingresos totales por período
plt.figure(figsize=(10, 6))
plt.bar(x= 'Total', width=0.2, height=0.1 )
plt.xlabel('Período' )
plt.ylabel('Ingresos Totales')
plt.title('Ingresos Totales por Período')
plt.xticks()
plt.show()

# %% [markdown]
# # Convierte los salarios a dolares
# ### Supongamos que el tipo de cambio es 1 dólar = 20 unidades de la moneda local

# %%
tipo_cambio=20
def convertir_a_dolares(salario):
    return salario / tipo_cambio

#df[].apply()

df['Total_dolares'] = df
df['1_salario_minimo_dolares'] = df()
df['2_salario_minimo_dolares'] = df
df['3_salario_minimo_dolares'] = df
df['5_salario_minimo_dolares'] = df

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-011126bd1f1e> in <cell line: 7>()
#       5 #df[].apply()
#       6
# ----> 7 df['Total_dolares'] = df
#       8 df['1_salario_minimo_dolares'] = df()
#       9 df['2_salario_minimo_dolares'] = df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3968             self._setitem_array(key, value)
#    3969         elif isinstance(value, DataFrame):
# -> 3970             self._set_item_frame_value(key, value)
#    3971         elif (
#    3972             is_list_like(value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    4123
#    4124         if len(value.columns) != 1:
# -> 4125             raise ValueError(
#    4126                 "Cannot set a DataFrame with multiple columns to the single "
#    4127                 f"column {key}"
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column Total_dolares

# %%
# @title Copia el token a en la repuesta de TEAMS
import hashlib

df_string = df.to_string()

# Calcular el hash MD5
md5_hash = hashlib.md5(df_string.encode()).hexdigest()

print("Token del DataFrame:")
print(md5_hash)
# Out:
# Token del DataFrame:
# ef99f833d022f0fef872d12ce976ded9
